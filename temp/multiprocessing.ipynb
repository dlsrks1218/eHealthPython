# %%
import parmap, tqdm
from multiprocessing import Manager, cpu_count

# %%
def a(x, d): 
    d[x] = 1
    
num_cores = cpu_count() # 사용할 cpu 코어 수. multiprocessing.cpu_count() 로 확인 가능 
print(num_cores)
manager = Manager()
d = manager.dict()

input_list = range(1, 11) 
# parmap.map(a, input_list, d, pm_pbar=True, pm_processes=num_cores)

# input_data = np.array_split(input_list, num_cores)
parmap.map(a, input_list, d, pm_pbar=True, pm_processes=num_cores)
# Out:
# 8
# 100%|██████████| 10/10 [00:00<00:00, 871.29it/s]
# [None, None, None, None, None, None, None, None, None, None]

# %%
text = "test"
def har(case, text):
    X = case[0]
    text + str(X)

case = ['ab', 'cd', 'ef']
res = parmap.map(har, case, 'text', pm_chunksize=num_cores)
for item in res:
    print(item)
# Out:
# None
# None
# None

# %%
import numpy as np
from scipy.stats import laplace

def lap_mechanism(original_data=[], loc=0, scale=0, N=0, sensitivity=0, epsilon=0, flag=0):
    def laprnd(loc,scale):
        s = laplace.rvs(loc, scale, None)
        return s
    
    if flag == 1:
        scale = sensitivity/epsilon
    if flag == 2:
        scale = (sensitivity/N)/(epsilon)
#     scale = (sensitivity/N)/(epsilon)
    noisy_data = list(map(lambda i: i + laprnd(0, scale)/N, original_data))
    return list(np.around(np.array(noisy_data)))

# %%
input_data = np.array_split(range(1, 10001), num_cores)
for arr in input_data:
    print(len(arr), arr)
    
# lap_mechanism(ori_avg_data, 0,0,len(data_res), 7000, 0.5, 1)
def func(input_data):
    res = []
    for arr in input_data:
        res.append(lap_mechanism(list(arr), 0,0,443,7000,0.5,1))
    return res

tmp = manager.list()

def b(x, tmp): 
    tmp.append(x)


res = parmap.map(b, range(1, 10001), tmp, pm_pbar=True, pm_processes=num_cores)

print(res)
# for item in res:
#     print(item)
# Out:
# 1250 [   1    2    3 ... 1248 1249 1250]
# 1250 [1251 1252 1253 ... 2498 2499 2500]
# 1250 [2501 2502 2503 ... 3748 3749 3750]
# 1250 [3751 3752 3753 ... 4998 4999 5000]
# 1250 [5001 5002 5003 ... 6248 6249 6250]
# 1250 [6251 6252 6253 ... 7498 7499 7500]
# 1250 [7501 7502 7503 ... 8748 8749 8750]
# 1250 [ 8751  8752  8753 ...  9998  9999 10000]
# 10016it [00:00, 20485.40it/s]
# ...
